# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import tensorflow.contrib.slim as slim  
import matplotlib.pyplot as plt
import numpy as np
import time
import math
from gumbel import *
from ops import *
Bernoulli = tf.contrib.distributions.Bernoulli

# %%
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
class Config(object):
    init_scale = 0.1
    training_epochs = 25
    batch_size = 128
    display_step = 100
    lr = 0.001
    max_grad_norm = 0.25
    vocab_size = 10000
    tau0=5.0 # initial temperature
    ANNEAL_RATE=0.1
    MIN_TEMP=0.1
    beta = 0.0001
    display_step =100
    obj = 'ER' # 'MLE','VB','ER'
    
    # Network Parameters
    input_size = 28
    hidden_size = 128
    output_size = 10
    num_steps = 28 # timesteps
    num_layers = 1
    output_size = 10
    K= 8

def Dropoutcell(config, is_training):
    cell = tf.contrib.rnn.BasicLSTMCell(config.hidden_size, forget_bias=0.0,state_is_tuple=True)
    if is_training:
        cell = tf.contrib.rnn.DropoutWrapper(cell,
                                             output_keep_prob=config.keep_prob,
                                             variational_recurrent=False,
                                             dtype=tf.float32)
    return cell

# %%
class Model(object):
    def __init__(self, is_training, config):
        training = tf.placeholder(tf.bool)
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        self.tau = tf.Variable(0.0, trainable=False)
        self.lr  = tf.Variable(0.0, trainable=False)
        self.input = tf.placeholder("float", [None, self.num_steps, config.input_size])
        self.targets = tf.placeholder("float", [None, config.output_size])
        
        with tf.variable_scope("model", reuse=tf.AUTO_REUSE ):
            self.initial_state = tf.zeros([self.batch_size,config.hidden_size*2])
            
            self.state = self.initial_state
            self.outputs = []
            self.ALL_z = []
            self.ALL_qz = []
            self.ALL_h = []
            self.ALL_state = []
        with tf.variable_scope("MRNN", reuse=tf.AUTO_REUSE):
            for time_step in range(self.num_steps):
                old_h, old_c = tf.split(value=self.state, num_or_size_splits=2, axis=1)
                with tf.variable_scope('logit_enc'):
                    logit_z = linear(self.input[:,time_step,:], config.K, name='x_zin') + \
                                linear(old_h, config.K, name='h_zin')
                q_z = tf.nn.softmax(logit_z)
                if is_training is True:
                    z = gumbel_softmax(logit_z,self.tau,hard=False)
                else:
                    z = softmax_sample(logit_z)
                self.ALL_z.append(z)
                self.ALL_qz.append(q_z)

                gates = linear(tf.concat([self.input[:,time_step,:], old_h], 1),\
                               config.hidden_size*config.K*4, name='gate')
                i, g, f, o = tf.split(value=gates, num_or_size_splits=4, axis=1)
                old_c_K = tf.tile(old_c,[1,config.K])
                new_c_K = tf.multiply(tf.sigmoid(f), old_c_K) + tf.multiply(tf.sigmoid(i), tf.tanh(g))
                new_h_K = tf.multiply(tf.sigmoid(o), tf.tanh(new_c_K))
                new_c_K = tf.reshape(new_c_K, [self.batch_size,config.K,config.hidden_size])
                new_h_K = tf.reshape(new_h_K, [self.batch_size,config.K,config.hidden_size])
                new_h = tf.einsum('nkd,nk->nd',new_h_K,z)
                new_c = tf.einsum('nkd,nk->nd',new_c_K,z)
                self.state = tf.concat([new_h, new_c], 1)
                self.ALL_h.append(new_h)
                self.ALL_state.append(self.state)
            self.logits = linear(new_h, config.output_size)
            
        self.NLL = tf.nn.softmax_cross_entropy_with_logits(logits=self.logits, labels=self.targets)
        
        ALL_q_z_tmp = tf.transpose(self.ALL_qz,[1,0,2])
        entropy = -ALL_q_z_tmp*tf.log(ALL_q_z_tmp+1e-20)
        self.entropy = tf.reduce_mean(tf.reduce_sum(entropy,[1, 2]))
        
        if config.obj == 'ER':
            self.cost = tf.reduce_mean(self.NLL) - config.beta*self.entropy
        elif config.obj == 'VB':
            self.cost = tf.reduce_mean(self.NLL) - self.entropy
        elif config.obj == 'MLE':
            self.cost = tf.reduce_mean(self.NLL)
            
        self.correct_pred = tf.equal(tf.argmax(self.logits,1), tf.argmax(self.targets,1))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_pred, tf.float32))
        
        if not is_training:
            return
    
        self.train_op = tf.train.AdamOptimizer(learning_rate=self.lr).minimize(self.cost)
    
        self.new_lr = tf.placeholder(tf.float32, shape=[], name="new_learning_rate")
        self.lr_update = tf.assign(self.lr, self.new_lr)
        self.new_tau = tf.placeholder(tf.float32, shape=[], name="new_tau")
        self.tau_update = tf.assign(self.tau, self.new_tau)
        
    def assign_lr(self, session, lr_value):
        session.run(self.lr_update, feed_dict={self.new_lr: lr_value})
    def assign_tau(self, session, tau_value):
        session.run(self.tau_update, feed_dict={self.new_tau: tau_value})

# %%
class Model(object):
    def __init__(self, is_training, config):
        training = tf.placeholder(tf.bool)
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        self.tau = tf.Variable(0.0, trainable=False)
        self.lr  = tf.Variable(0.0, trainable=False)
        self.input = tf.placeholder("float", [None, self.num_steps, config.input_size])
        self.targets = tf.placeholder("float", [None, config.output_size])
        
        with tf.variable_scope("model", reuse=tf.AUTO_REUSE ):
            self.initial_state = tf.zeros([self.batch_size,config.hidden_size])
            self.initial_cell = tf.zeros([self.batch_size,config.hidden_size*config.K])
            
            self.state = self.initial_state
            self.outputs = []
            self.ALL_z = []
            self.ALL_qz = []
            self.ALL_h = []
            self.ALL_state = []
        with tf.variable_scope("MRNN", reuse=tf.AUTO_REUSE):
            for time_step in range(self.num_steps):
                old_h = self.state
                with tf.variable_scope('logit_enc'):
                    logit_z = linear(self.input[:,time_step,:], config.K, name='x_zin') + \
                                linear(old_h, config.K, name='h_zin')
                q_z = tf.nn.softmax(logit_z)
                if is_training is True:
                    z = gumbel_softmax(logit_z,self.tau,hard=True)
                else:
                    z = softmax_sample(logit_z)
                self.ALL_z.append(z)
                self.ALL_qz.append(q_z)

                gates = linear(tf.concat([self.input[:,time_step,:], old_h], 1),\
                               config.hidden_size*config.K*4, name='gate')
                i, g, f, o = tf.split(value=gates, num_or_size_splits=4, axis=1)
                old_c_K = tf.tile(old_c,[1,config.K])
                new_c_K = tf.multiply(tf.sigmoid(f), old_c_K) + tf.multiply(tf.sigmoid(i), tf.tanh(g))
                new_h_K = tf.multiply(tf.sigmoid(o), tf.tanh(new_c_K))
                new_c_K = tf.reshape(new_c_K, [self.batch_size,config.K,config.hidden_size])
                new_h_K = tf.reshape(new_h_K, [self.batch_size,config.K,config.hidden_size])
                new_h = tf.einsum('nkd,nk->nd',new_h_K,z)
                new_c = tf.einsum('nkd,nk->nd',new_c_K,z)
                self.state = tf.concat([new_h, new_c], 1)
                self.ALL_h.append(new_h)
                self.ALL_state.append(self.state)
            self.logits = linear(new_h, config.output_size)
            
        self.NLL = tf.nn.softmax_cross_entropy_with_logits(logits=self.logits, labels=self.targets)
        
        ALL_q_z_tmp = tf.transpose(self.ALL_qz,[1,0,2])
        entropy = -ALL_q_z_tmp*tf.log(ALL_q_z_tmp+1e-20)
        self.entropy = tf.reduce_mean(tf.reduce_sum(entropy,[1, 2]))
        
#         self.cost = self.NLL - config.beta*self.entropy
        self.cost = tf.reduce_mean(self.NLL)
        self.correct_pred = tf.equal(tf.argmax(self.logits,1), tf.argmax(self.targets,1))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_pred, tf.float32))
        
        if not is_training:
            return
    
#         tvars = tf.trainable_variables()
#         grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),config.max_grad_norm)
#         optimizer = tf.train.GradientDescentOptimizer(self.lr)
#         self.train_op = optimizer.apply_gradients(
#             zip(grads, tvars),
#             global_step=tf.contrib.framework.get_or_create_global_step())
        self.train_op = tf.train.AdamOptimizer(learning_rate=self.lr).minimize(self.cost)
    
        self.new_lr = tf.placeholder(tf.float32, shape=[], name="new_learning_rate")
        self.lr_update = tf.assign(self.lr, self.new_lr)
        self.new_tau = tf.placeholder(tf.float32, shape=[], name="new_tau")
        self.tau_update = tf.assign(self.tau, self.new_tau)
        
    def assign_lr(self, session, lr_value):
        session.run(self.lr_update, feed_dict={self.new_lr: lr_value})
    def assign_tau(self, session, tau_value):
        session.run(self.tau_update, feed_dict={self.new_tau: tau_value})

# %%
# # Initializing the variables
# init = tf.global_variables_initializer()

# # Launch the graph
# sess = tf.Session()
# sess.run(init)

# batch_x, batch_y = mnist.train.next_batch(batch_size)
# batch_x = batch_x.reshape((batch_size, n_steps, n_input))

# print(sess.run([dis_h], feed_dict={x: batch_x, training: False})[0])
# print(sess.run([z], feed_dict={x: batch_x, training: False})[0])

config = Config()
eval_config = Config()
eval_config.batch_size = 1
eval_config.num_steps = 1

initializer = tf.random_uniform_initializer(-config.init_scale,config.init_scale)

with tf.name_scope("Train"):
    with tf.variable_scope("Model", reuse=None, initializer=initializer):
        m = Model(is_training=True, config=config)

with tf.name_scope("Valid"):
    with tf.variable_scope("Model", reuse=True, initializer=initializer):
        mvalid = Model(is_training=False, config=config)

with tf.name_scope("Test"):
    with tf.variable_scope("Model", reuse=True, initializer=initializer):
        mtest = Model(is_training=False, config=config)

# %%
# Initializing the variables
init = tf.global_variables_initializer()
saver = tf.train.Saver()
# Launch the graph
sess = tf.Session()
sess.run(init)
training_mis = []
training_loss = []
training_res = []
training_KL = []
valid_loss = [np.inf]
m.assign_lr(sess, config.lr)
# Training cycle
for epoch in range(config.training_epochs):
    avg_cost = 0.
    total_batch = int(mnist.train.num_examples/config.batch_size)
    # Loop over all batches
    for i in range(total_batch):
        start = time.time()
        batch_x, batch_y = mnist.train.next_batch(config.batch_size)
        # Run optimization op (backprop) and cost op (to get loss value)
        batch_x = batch_x.reshape((config.batch_size, config.num_steps, config.input_size))
        
        np_temp=np.maximum(config.tau0*np.exp(-config.ANNEAL_RATE*epoch),config.MIN_TEMP)
        m.assign_tau(sess, np_temp)
        temp_lr, temp_tau = sess.run([m.lr, m.tau])
        
#         _, c, acc, batch_res, batch_KL = sess.run([optimizer, cost, accuracy, res, KL], feed_dict={x: batch_x, y: batch_y, training: True})
        _, c, acc = sess.run([m.train_op, m.cost, m.accuracy], feed_dict={m.input: batch_x, \
                                                                            m.targets: batch_y})
        # Compute average loss
        avg_cost += c / total_batch
        training_mis.append(1-acc)
        training_loss.append(c)
#         training_res.append(batch_res)
#         training_KL.append(batch_KL)
        end = time.time()
        train_time = (end-start) * config.display_step
        if (i+1) % config.display_step == 0:
            # Calculate batch loss and accuracy
            print ("Iter " + str((i+1)*config.batch_size) + \
                    ", Minibatch Loss= " + "{:.6f}".format(c) + \
                    ", Training Accuracy= " + "{:.5f}".format(acc) +\
                    ", Training Time= " + "{:.3f}".format(train_time))
    print("Learning rate: %f, Temperature: %f" % (temp_lr, temp_tau))
    print ("Epoch:", '%04d' % (epoch+1), "cost=","{:.9f}".format(avg_cost))
    print('-'*50)
    avg_cost = 0.
    avg_acc = 0.
    total_batch = int(mnist.test.num_examples/config.batch_size)
    # Loop over all batches
    for i in range(total_batch):
        batch_x, batch_y = mnist.test.next_batch(config.batch_size)
        # Run optimization op (backprop) and cost op (to get loss value)
        batch_x = batch_x.reshape((config.batch_size, config.num_steps, config.input_size))
        c, acc = sess.run([mvalid.cost, mvalid.accuracy], feed_dict={mvalid.input: batch_x, \
                                                                       mvalid.targets: batch_y})
        # Compute average loss
        avg_cost += c / total_batch
        avg_acc += acc / total_batch
    valid_loss.append(avg_cost)
    print("Valid_cost=","{:.9f}".format(avg_cost))
#     if epoch > 10:
#         if valid_loss[-2] - valid_loss[-1] < 0:
#             break
    print('-'*50)
saver.save(sess, "./model.ckpt")
print("Optimization Finished!")
# Out:
# Iter 12800, Minibatch Loss= 1.087310, Training Accuracy= 0.68750, Training Time= 3.472
# Iter 25600, Minibatch Loss= 0.533359, Training Accuracy= 0.83594, Training Time= 3.504
# Iter 38400, Minibatch Loss= 0.492305, Training Accuracy= 0.84375, Training Time= 3.484
# Iter 51200, Minibatch Loss= 0.489842, Training Accuracy= 0.85938, Training Time= 3.652
# Learning rate: 0.001000, Temperature: 5.000000
# Epoch: 0001 cost= 0.882961839
# --------------------------------------------------
# Valid_cost= 0.896675956
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.349256, Training Accuracy= 0.89062, Training Time= 3.474
# Iter 25600, Minibatch Loss= 0.183394, Training Accuracy= 0.95312, Training Time= 3.470
# Iter 38400, Minibatch Loss= 0.280247, Training Accuracy= 0.92188, Training Time= 3.461
# Iter 51200, Minibatch Loss= 0.190449, Training Accuracy= 0.93750, Training Time= 3.484
# Learning rate: 0.001000, Temperature: 4.524187
# Epoch: 0002 cost= 0.272409095
# --------------------------------------------------
# Valid_cost= 0.591740627
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.135384, Training Accuracy= 0.95312, Training Time= 3.482
# Iter 25600, Minibatch Loss= 0.301413, Training Accuracy= 0.90625, Training Time= 3.493
# Iter 38400, Minibatch Loss= 0.240439, Training Accuracy= 0.92969, Training Time= 3.495
# Iter 51200, Minibatch Loss= 0.176957, Training Accuracy= 0.92969, Training Time= 3.516
# Learning rate: 0.001000, Temperature: 4.093654
# Epoch: 0003 cost= 0.171856034
# --------------------------------------------------
# Valid_cost= 0.512955538
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.147214, Training Accuracy= 0.95312, Training Time= 3.474
# Iter 25600, Minibatch Loss= 0.139148, Training Accuracy= 0.96094, Training Time= 3.523
# Iter 38400, Minibatch Loss= 0.207129, Training Accuracy= 0.93750, Training Time= 3.507
# Iter 51200, Minibatch Loss= 0.107045, Training Accuracy= 0.96094, Training Time= 3.511
# Learning rate: 0.001000, Temperature: 3.704091
# Epoch: 0004 cost= 0.120387248
# --------------------------------------------------
# Valid_cost= 0.550050293
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.155691, Training Accuracy= 0.94531, Training Time= 3.485
# Iter 25600, Minibatch Loss= 0.027845, Training Accuracy= 0.98438, Training Time= 3.521
# Iter 38400, Minibatch Loss= 0.062246, Training Accuracy= 0.97656, Training Time= 3.489
# Iter 51200, Minibatch Loss= 0.074987, Training Accuracy= 0.97656, Training Time= 3.486
# Learning rate: 0.001000, Temperature: 3.351600
# Epoch: 0005 cost= 0.097674315
# --------------------------------------------------
# Valid_cost= 0.460460256
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.024761, Training Accuracy= 0.99219, Training Time= 3.502
# Iter 25600, Minibatch Loss= 0.121992, Training Accuracy= 0.96094, Training Time= 3.482
# Iter 38400, Minibatch Loss= 0.015021, Training Accuracy= 1.00000, Training Time= 3.493
# Iter 51200, Minibatch Loss= 0.015816, Training Accuracy= 0.99219, Training Time= 3.453
# Learning rate: 0.001000, Temperature: 3.032653
# Epoch: 0006 cost= 0.075912814
# --------------------------------------------------
# Valid_cost= 0.361084096
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.048198, Training Accuracy= 0.99219, Training Time= 3.457
# Iter 25600, Minibatch Loss= 0.075531, Training Accuracy= 0.96875, Training Time= 3.603
# Iter 38400, Minibatch Loss= 0.046316, Training Accuracy= 0.99219, Training Time= 3.477
# Iter 51200, Minibatch Loss= 0.063292, Training Accuracy= 0.97656, Training Time= 3.477
# Learning rate: 0.001000, Temperature: 2.744058
# Epoch: 0007 cost= 0.064969404
# --------------------------------------------------
# Valid_cost= 0.317804120
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.028200, Training Accuracy= 0.99219, Training Time= 3.481
# Iter 25600, Minibatch Loss= 0.046271, Training Accuracy= 0.98438, Training Time= 4.017
# Iter 38400, Minibatch Loss= 0.044282, Training Accuracy= 0.98438, Training Time= 3.514
# Iter 51200, Minibatch Loss= 0.084484, Training Accuracy= 0.95312, Training Time= 3.508
# Learning rate: 0.001000, Temperature: 2.482927
# Epoch: 0008 cost= 0.056851424
# --------------------------------------------------
# Valid_cost= 0.305895734
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.195357, Training Accuracy= 0.94531, Training Time= 3.462
# Iter 25600, Minibatch Loss= 0.039008, Training Accuracy= 0.98438, Training Time= 3.502
# Iter 38400, Minibatch Loss= 0.056212, Training Accuracy= 0.98438, Training Time= 3.482
# Iter 51200, Minibatch Loss= 0.052046, Training Accuracy= 0.98438, Training Time= 3.480
# Learning rate: 0.001000, Temperature: 2.246645
# Epoch: 0009 cost= 0.049283209
# --------------------------------------------------
# Valid_cost= 0.264229905
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.014094, Training Accuracy= 0.99219, Training Time= 3.518
# Iter 25600, Minibatch Loss= 0.024030, Training Accuracy= 1.00000, Training Time= 3.466
# Iter 38400, Minibatch Loss= 0.084578, Training Accuracy= 0.96875, Training Time= 3.674
# Iter 51200, Minibatch Loss= 0.008234, Training Accuracy= 0.99219, Training Time= 3.468
# Learning rate: 0.001000, Temperature: 2.032848
# Epoch: 0010 cost= 0.043627721
# --------------------------------------------------
# Valid_cost= 0.200408288
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.087920, Training Accuracy= 0.97656, Training Time= 3.480
# Iter 25600, Minibatch Loss= 0.090267, Training Accuracy= 0.98438, Training Time= 3.525
# Iter 38400, Minibatch Loss= 0.034688, Training Accuracy= 0.99219, Training Time= 3.471
# Iter 51200, Minibatch Loss= 0.027379, Training Accuracy= 0.98438, Training Time= 3.473
# Learning rate: 0.001000, Temperature: 1.839397
# Epoch: 0011 cost= 0.038259512
# --------------------------------------------------
# Valid_cost= 0.164776763
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.015513, Training Accuracy= 1.00000, Training Time= 3.479
# Iter 25600, Minibatch Loss= 0.059622, Training Accuracy= 0.97656, Training Time= 3.470
# Iter 38400, Minibatch Loss= 0.069438, Training Accuracy= 0.98438, Training Time= 3.584
# Iter 51200, Minibatch Loss= 0.008670, Training Accuracy= 1.00000, Training Time= 3.517
# Learning rate: 0.001000, Temperature: 1.664355
# Epoch: 0012 cost= 0.035270707
# --------------------------------------------------
# Valid_cost= 0.133327052
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.053888, Training Accuracy= 0.96875, Training Time= 3.467
# Iter 25600, Minibatch Loss= 0.011297, Training Accuracy= 0.99219, Training Time= 3.484
# Iter 38400, Minibatch Loss= 0.071214, Training Accuracy= 0.98438, Training Time= 3.497
# Iter 51200, Minibatch Loss= 0.062788, Training Accuracy= 0.99219, Training Time= 3.448
# Learning rate: 0.001000, Temperature: 1.505971
# Epoch: 0013 cost= 0.034114046
# --------------------------------------------------
# Valid_cost= 0.124587617
# --------------------------------------------------
# Iter 12800, Minibatch Loss= -0.001015, Training Accuracy= 1.00000, Training Time= 3.466
# Iter 25600, Minibatch Loss= 0.010030, Training Accuracy= 0.99219, Training Time= 3.487
# Iter 38400, Minibatch Loss= -0.002460, Training Accuracy= 1.00000, Training Time= 3.528
# Iter 51200, Minibatch Loss= -0.001788, Training Accuracy= 1.00000, Training Time= 3.478
# Learning rate: 0.001000, Temperature: 1.362659
# Epoch: 0014 cost= 0.029142287
# --------------------------------------------------
# Valid_cost= 0.133474255
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.022216, Training Accuracy= 0.99219, Training Time= 3.503
# Iter 25600, Minibatch Loss= 0.063839, Training Accuracy= 0.99219, Training Time= 3.492
# Iter 38400, Minibatch Loss= 0.022117, Training Accuracy= 0.98438, Training Time= 3.492
# Iter 51200, Minibatch Loss= 0.008596, Training Accuracy= 0.99219, Training Time= 3.520
# Learning rate: 0.001000, Temperature: 1.232985
# Epoch: 0015 cost= 0.029500421
# --------------------------------------------------
# Valid_cost= 0.101692141
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.031916, Training Accuracy= 0.98438, Training Time= 3.474
# Iter 25600, Minibatch Loss= 0.008948, Training Accuracy= 1.00000, Training Time= 3.478
# Iter 38400, Minibatch Loss= 0.003097, Training Accuracy= 1.00000, Training Time= 3.509
# Iter 51200, Minibatch Loss= 0.012727, Training Accuracy= 0.99219, Training Time= 3.559
# Learning rate: 0.001000, Temperature: 1.115651
# Epoch: 0016 cost= 0.027251890
# --------------------------------------------------
# Valid_cost= 0.110252093
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.007835, Training Accuracy= 0.99219, Training Time= 3.471
# Iter 25600, Minibatch Loss= 0.007786, Training Accuracy= 0.99219, Training Time= 3.527
# Iter 38400, Minibatch Loss= 0.026340, Training Accuracy= 0.99219, Training Time= 3.479
# Iter 51200, Minibatch Loss= 0.019012, Training Accuracy= 0.99219, Training Time= 3.497
# Learning rate: 0.001000, Temperature: 1.009483
# Epoch: 0017 cost= 0.024747241
# --------------------------------------------------
# Valid_cost= 0.086041783
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.046498, Training Accuracy= 0.98438, Training Time= 3.470
# Iter 25600, Minibatch Loss= 0.011169, Training Accuracy= 0.99219, Training Time= 3.459
# Iter 38400, Minibatch Loss= 0.074517, Training Accuracy= 0.98438, Training Time= 3.527
# Iter 51200, Minibatch Loss= 0.004665, Training Accuracy= 1.00000, Training Time= 3.511
# Learning rate: 0.001000, Temperature: 0.913418
# Epoch: 0018 cost= 0.022950116
# --------------------------------------------------
# Valid_cost= 0.088510363
# --------------------------------------------------
# Iter 12800, Minibatch Loss= -0.000172, Training Accuracy= 1.00000, Training Time= 3.534
# Iter 25600, Minibatch Loss= 0.030948, Training Accuracy= 0.97656, Training Time= 3.502
# Iter 38400, Minibatch Loss= 0.020288, Training Accuracy= 0.99219, Training Time= 3.493
# Iter 51200, Minibatch Loss= 0.044014, Training Accuracy= 0.98438, Training Time= 3.509
# Learning rate: 0.001000, Temperature: 0.826494
# Epoch: 0019 cost= 0.021075653
# --------------------------------------------------
# Valid_cost= 0.105252758
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.032680, Training Accuracy= 0.97656, Training Time= 3.452
# Iter 25600, Minibatch Loss= 0.019251, Training Accuracy= 0.99219, Training Time= 3.834
# Iter 38400, Minibatch Loss= 0.060659, Training Accuracy= 0.97656, Training Time= 3.474
# Iter 51200, Minibatch Loss= 0.118291, Training Accuracy= 0.97656, Training Time= 3.468
# Learning rate: 0.001000, Temperature: 0.747843
# Epoch: 0020 cost= 0.025920679
# --------------------------------------------------
# Valid_cost= 0.068332694
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.098883, Training Accuracy= 0.95312, Training Time= 3.535
# Iter 25600, Minibatch Loss= 0.005111, Training Accuracy= 1.00000, Training Time= 3.498
# Iter 38400, Minibatch Loss= 0.016465, Training Accuracy= 0.99219, Training Time= 3.482
# Iter 51200, Minibatch Loss= 0.000327, Training Accuracy= 1.00000, Training Time= 3.465
# Learning rate: 0.001000, Temperature: 0.676676
# Epoch: 0021 cost= 0.018164132
# --------------------------------------------------
# Valid_cost= 0.064523946
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.011918, Training Accuracy= 0.99219, Training Time= 3.519
# Iter 25600, Minibatch Loss= 0.013464, Training Accuracy= 0.99219, Training Time= 3.538
# Iter 38400, Minibatch Loss= 0.005682, Training Accuracy= 1.00000, Training Time= 3.454
# Iter 51200, Minibatch Loss= 0.020861, Training Accuracy= 0.98438, Training Time= 3.478
# Learning rate: 0.001000, Temperature: 0.612282
# Epoch: 0022 cost= 0.018544944
# --------------------------------------------------
# Valid_cost= 0.069450057
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.025764, Training Accuracy= 0.99219, Training Time= 3.463
# Iter 25600, Minibatch Loss= 0.004126, Training Accuracy= 1.00000, Training Time= 3.497
# Iter 38400, Minibatch Loss= 0.000934, Training Accuracy= 1.00000, Training Time= 3.489
# Iter 51200, Minibatch Loss= 0.066528, Training Accuracy= 0.99219, Training Time= 3.488
# Learning rate: 0.001000, Temperature: 0.554016
# Epoch: 0023 cost= 0.018330711
# --------------------------------------------------
# Valid_cost= 0.069820904
# --------------------------------------------------
# Iter 12800, Minibatch Loss= 0.030067, Training Accuracy= 0.99219, Training Time= 3.459
# Iter 25600, Minibatch Loss= 0.040503, Training Accuracy= 0.98438, Training Time= 3.470
# Iter 38400, Minibatch Loss= 0.003435, Training Accuracy= 1.00000, Training Time= 3.478
# Iter 51200, Minibatch Loss= 0.028616, Training Accuracy= 0.99219, Training Time= 3.516
# Learning rate: 0.001000, Temperature: 0.501294
# Epoch: 0024 cost= 0.019099102
# --------------------------------------------------
# Valid_cost= 0.061121275
# --------------------------------------------------
# Iter 12800, Minibatch Loss= -0.001830, Training Accuracy= 1.00000, Training Time= 3.473
# Iter 25600, Minibatch Loss= 0.002487, Training Accuracy= 1.00000, Training Time= 3.488
# Iter 38400, Minibatch Loss= 0.002666, Training Accuracy= 1.00000, Training Time= 3.481
# Iter 51200, Minibatch Loss= 0.006476, Training Accuracy= 1.00000, Training Time= 3.505
# Learning rate: 0.001000, Temperature: 0.453590
# Epoch: 0025 cost= 0.016197401
# --------------------------------------------------
# Valid_cost= 0.066630847
# --------------------------------------------------
# Optimization Finished!

# %%
# Testing cycle
for epoch in range(1):
    avg_cost = 0.
    avg_acc = 0.
    total_batch = int(mnist.test.num_examples/config.batch_size)
    # Loop over all batches
    for i in range(total_batch):
        batch_x, batch_y = mnist.test.next_batch(config.batch_size)
        # Run optimization op (backprop) and cost op (to get loss value)
        batch_x = batch_x.reshape((config.batch_size, config.num_steps, config.input_size))
        c, acc = sess.run([mvalid.cost, mvalid.accuracy], feed_dict={mvalid.input: batch_x, \
                                                                       mvalid.targets: batch_y})
        # Compute average loss
        avg_cost += c / total_batch
        avg_acc += acc / total_batch


print ("Epoch:", '%04d' % (epoch+1), "cost=","{:.9f}".format(avg_cost), "acc=","{:.9f}".format(avg_acc))
# Out:
# Epoch: 0001 cost= 0.068463593 acc= 0.980368590

# %%
import os
URL = 'K='+str(config.K)+'_beta='+str(config.beta)
if not os.path.exists(URL):
    os.makedirs(URL)

Total_prob = 0
eval_config = Config()
for i in range(10):
    temp_data = mnist.train.images[mnist.train.labels[:,i]==1,:]
    temp_label = mnist.train.labels[mnist.train.labels[:,i]==1,:]
    temp_im = np.reshape(temp_data,[-1,eval_config.num_steps,eval_config.input_size])
    batch_size = temp_im.shape[0]
    eval_config.batch_size = batch_size
    with tf.variable_scope("Model", reuse=True, initializer=initializer):
        temp_m = Model(is_training=False, config=eval_config)
    temp_z = sess.run(temp_m.ALL_z, feed_dict={temp_m.input: temp_im, temp_m.targets: temp_label})
    temp_z = np.transpose(temp_z, (1, 0, 2))
#     print(np.sum(np.sum(temp_z, axis=0), axis=0))
#     print(np.einsum('ijk->k',temp_z)/np.sum(temp_z))
    prob = np.einsum('ijk->k',temp_z)/np.sum(temp_z)
    Total_prob += prob
    
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.imshow(temp_im[0])
    
    plt.subplot(1,2,2)
    xs = np.arange(eval_config.K)
    plt.bar(xs, prob, alpha=0.8)
    plt.savefig(URL+'/dist_'+str(i)+'.png')
    plt.show()
    
    
#     print(sess.run(logit_z, feed_dict={x: temp_im, y: temp_label, training: True}))
Total_prob = Total_prob/10
xs = np.arange(eval_config.K)
plt.figure(figsize=(5,5))
plt.bar(xs, Total_prob, alpha=0.8)
plt.savefig(URL+'/stat.png')
plt.show()

# %%
index = 2
for i in range(10):
    temp_data = mnist.train.images[mnist.train.labels[:,i]==1,:]
    temp_label = mnist.train.labels[mnist.train.labels[:,i]==1,:]
    temp_im = np.reshape(temp_data,[-1,config.num_steps,config.input_size])
    batch_x = temp_im[:config.batch_size,:]
    batch_y = temp_label[:config.batch_size,:]
    plt.figure(figsize=(10,10))
    plt.subplot(3,1,1)
    plt.imshow(batch_x[index])
    temp_z, temp_q_z = sess.run([mvalid.ALL_z, mvalid.ALL_qz], feed_dict={mvalid.input: batch_x, mvalid.targets: batch_y})
    temp_z = np.transpose(temp_z, (1, 0, 2))
    temp = temp_q_z
    temp_q_z = np.transpose(temp_q_z, (1, 0, 2))
    plt.subplot(3,1,2)
    plt.imshow(temp_z[index].T)
    plt.subplot(3,1,3)
    plt.imshow(temp_q_z[index].T)
    plt.savefig(URL+'/state_'+str(i)+'.png')
    plt.show()
#     print(np.reshape(temp,[-1,K]))
#     print(np.argmax(temp_z, axis=2))

# %%
# Calculate accuracy for 128 mnist test images
plt.figure()
plt.plot(range(1,len(training_mis)+1),training_mis,'b')
plt.show()
plt.figure()
plt.plot(range(1,len(training_loss)+1),training_loss,'r')
plt.show()
